# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

df = pd.read_csv("C:/Users/Charlie Jeff/Desktop/Assignment/loanP_Train.csv") #reading the dataset

# %%
df.head() #view table
# Out:
#   Loan_ID Gender Marital_Status Dependents Graduate Self_Employed  \
# 0  LI0100   Male         Single          0      Yes            No
# 1  LI0101   Male        Married          1      Yes            No
# 2  LI0102   Male        Married          0      Yes           Yes
# 3  LI0103   Male        Married          0       No            No
# 4  LI0104   Male         Single          0      Yes            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.describe() #check summary
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       599.000000         599.000000  578.000000        585.000000
# mean       5420.687813        1563.913055  145.434256        342.461538
# std        6169.168633        2456.618360   84.596463         64.868352
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2874.000000           0.000000  100.000000        360.000000
# 50%        3812.000000        1210.000000  126.500000        360.000000
# 75%        5807.500000        2279.000000  165.000000        360.000000
# max       81000.000000       33837.000000  700.000000        480.000000
#
#        Credit_History
# count       550.00000
# mean          0.84000
# std           0.36694
# min           0.00000
# 25%           1.00000
# 50%           1.00000
# 75%           1.00000
# max           1.00000

# %%
df['LoanAmount']. hist(bins=50) #graph data
# Out:
# <Axes: >

# %%
df['ApplicantIncome']. hist(bins=50) #graph data
# Out:
# <Axes: >

# %%
df.apply(lambda x: sum(x.isnull()),axis=0) #check missing values
# Out:
# Loan_ID               0
# Gender               13
# Marital_Status        3
# Dependents           15
# Graduate              0
# Self_Employed        30
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           21
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64
